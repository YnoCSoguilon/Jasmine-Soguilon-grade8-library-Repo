# %% [markdown]
# <a href="https://colab.research.google.com/github/YnoCSoguilon/Jasmine-Soguilon-grade8-library-Repo/blob/main/Jasmine_Soguilon_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
